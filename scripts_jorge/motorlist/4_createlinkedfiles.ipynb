# %%
import json
import os
import pandas as pd
import numpy as np
import re

current_dir = os.getcwd()
parent_dir = os.path.join(current_dir, os.pardir, os.pardir)
parent_dir = os.path.abspath(parent_dir)

bronze_dir = os.path.join(parent_dir, 'datasets', 'motorlist', '2_bronze')
bronze_files = os.listdir(bronze_dir)
silver_dir = os.path.join(parent_dir, 'datasets', 'motorlist', '3_silver')
silver_files = os.listdir(silver_dir)
motorlist_relationships_dir = os.path.join(parent_dir, 'datasets', 'motorlist', 'relationships')

km77_dir = os.path.join(parent_dir, 'datasets', 'km77')
km77_data_dir = os.path.join(km77_dir, 'Transformed_data')
km77_folders = os.listdir(km77_data_dir)
km77_relationships_dir = os.path.join(km77_dir, 'relationships')

# %%
brand = 'Audi'

# %% [markdown]
# ### 1. KM 77

# %%
brand_folder = os.path.join(km77_data_dir, brand)
brand_files = os.listdir(brand_folder)

# %%
# Open all brand files, extract name and save in a set
brand_names = set()
for file in brand_files:
    with open(os.path.join(brand_folder, file), 'r', encoding='utf-8') as f:
        data = json.load(f)
        name = data['name']
        brand_names.add(name)

brand_names = sorted(list(brand_names))

# %%
#create a dataframe with the brand data
brand_df = pd.DataFrame(brand_names, columns=['km77_name'])
# Create empty column 'cleaned_name'
brand_df['cleaned_name'] = ''
# Rearrenge the columns so clenaed_name is the first column
brand_df = brand_df[['cleaned_name', 'km77_name']]
brand_df
# Out:
#    cleaned_name         km77_name
# 0                              A2
# 1                    A3 3 puertas
# 2                    A3 5 puertas
# 3                       A3 Cabrio
# 4                        A3 Sedan
# 5                        A3 Sedán
# 6                    A3 Sportback
# 7                    A3 allstreet
# 8                    A4 4 puertas
# 9                        A4 Avant
# 10                     A4 Berlina
# 11                     A4 allroad
# 12                             A5
# 13                       A5 Avant
# 14                      A5 Cabrio
# 15                       A5 Coupé
# 16                   A5 Sportback
# 17                             A6
# 18                       A6 Avant
# 19                     A6 Berlina
# 20                     A6 allroad
# 21                   A7 Sportback
# 22                             A8
# 23                           A8 L
# 24                       A8 Largo
# 25                         Cabrio
# 26                             Q2
# 27                             Q3
# 28                   Q3 Sportback
# 29                             Q5
# 30                   Q5 Sportback
# 31                             Q6
# 32                   Q6 Sportback
# 33                             Q7
# 34                             Q8
# 35                   Q8 Sportback
# 36                       R8 Coupé
# 37                      R8 Spyder
# 38                       TT Coupé
# 39                    TT Roadster
# 40                         e-tron
# 41                      e-tron GT
# 42               e-tron Sportback

# %%
# Save the dataframe to a xsxl file
brand_df.to_excel(os.path.join(km77_relationships_dir, f'{brand.lower()}_cars.xlsx'), index=False)

# %% [markdown]
# ### 2. Motorlist

# %%
# create a dataframe with all the json files
dicts = []

for file in silver_files:
    with open(os.path.join(silver_dir, file), 'r', encoding="utf-8") as f:
        data = json.load(f)
        dicts.append(data)

df = pd.DataFrame(dicts)

df.head()
# Out:
#   Production years Displacement, cc       Fuel system Power output, hp  \
# 0        2008-2015           1598.0       Common Rail            120.0
# 1        2000-2002           2387.0       Common Rail            140.0
# 2        2002-2010           1970.0  direct injection            165.0
# 3        2003-2010           1910.0       Common Rail            150.0
# 4        2005-2010           3195.0  direct injection            260.0
#
#   Torque output, Nm Cylinder block    Block head Cylinder bore, mm  \
# 0         300 – 320   cast iron R4  aluminum 16v              79.5
# 1             305.0   cast iron R5  aluminum 10v              82.0
# 2             206.0   cast iron R4  aluminum 16v              83.0
# 3             305.0   cast iron R4  aluminum 16v              82.0
# 4             322.0    aluminum V6  aluminum 24v              89.0
#
#   Piston stroke, mm Compression ratio  ... Optimal revs  \
# 0              80.5              16.5  ...          NaN
# 1              90.4             18.45  ...          NaN
# 2              91.0              11.3  ...          NaN
# 3              90.4              17.5  ...          NaN
# 4              85.6             11.25  ...          NaN
#
#   Oil change volume including oil filter Oil filters Cooling, overall volume  \
# 0                                    NaN         NaN                     NaN
# 1                                    NaN         NaN                     NaN
# 2                                    NaN         NaN                     NaN
# 3                                    NaN         NaN                     NaN
# 4                                    NaN         NaN                     NaN
#
#   Dry weight (base engine) Dry weight, kg  \
# 0                      NaN            NaN
# 1                      NaN            NaN
# 2                      NaN            NaN
# 3                      NaN            NaN
# 4                      NaN            NaN
#
#   Combustion chamber working volume, cc  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Engine lifespan, thousand km— official information Max RPM Type
# 0                                                NaN     NaN  NaN
# 1                                                NaN     NaN  NaN
# 2                                                NaN     NaN  NaN
# 3                                                NaN     NaN  NaN
# 4                                                NaN     NaN  NaN
#
# [5 rows x 182 columns]

# %%
df['car_info'] = df['car_info'].apply(lambda x: np.array(x))
df['car_info']
# Out:
# 0       [[Alfa Romeo MiTo I, 2008], [Alfa Romeo MiTo I...
# 1       [[Alfa Romeo 156, 2000], [Alfa Romeo 156, 2001...
# 2       [[Alfa Romeo 156, 2002], [Alfa Romeo 156, 2003...
# 3       [[Alfa Romeo 147, 2005], [Alfa Romeo 147, 2006...
# 4       [[Alfa Romeo 159, 2005], [Alfa Romeo 159, 2006...
#                               ...
# 1359                                                   []
# 1360                                                   []
# 1361                                                   []
# 1362    [[Ford Scorpio, 1991], [Ford Scorpio, 1992], [...
# 1363    [[Ford Edge, 2014], [Ford F-Series, 2014], [Fo...
# Name: car_info, Length: 1364, dtype: object

# %%
# remove the empty lists of the car_info column
empty_car_infor_filt = df['car_info'].map(len) > 0
clean_car_df = df[empty_car_infor_filt]
clean_car_df
# Out:
#      Production years Displacement, cc       Fuel system Power output, hp  \
# 0           2008-2015           1598.0       Common Rail            120.0
# 1           2000-2002           2387.0       Common Rail            140.0
# 2           2002-2010           1970.0  direct injection            165.0
# 3           2003-2010           1910.0       Common Rail            150.0
# 4           2005-2010           3195.0  direct injection            260.0
# ...               ...              ...               ...              ...
# 1355        2005-2010           2400.0       Common Rail            185.0
# 1356        1995-2001           2460.0  direct injection            140.0
# 1357              NaN           5480.0               NaN              NaN
# 1362              NaN           1812.0        carburetor             82.0
# 1363              NaN           2694.0  direct injection        315 – 335
#
#      Torque output, Nm Cylinder block    Block head Cylinder bore, mm  \
# 0            300 – 320   cast iron R4  aluminum 16v              79.5
# 1                305.0   cast iron R5  aluminum 10v              82.0
# 2                206.0   cast iron R4  aluminum 16v              83.0
# 3                305.0   cast iron R4  aluminum 16v              82.0
# 4                322.0    aluminum V6  aluminum 24v              89.0
# ...                ...            ...           ...               ...
# 1355             400.0    aluminum R5  aluminum 20v              81.0
# 1356             290.0   cast iron R5  aluminum 10v              81.0
# 1357               NaN            NaN           NaN             98,43
# 1362             135.0            NaN           NaN              80.0
# 1363         475 – 515             V6           24v              83.0
#
#      Piston stroke, mm Compression ratio  ... Optimal revs  \
# 0                 80.5              16.5  ...          NaN
# 1                 90.4             18.45  ...          NaN
# 2                 91.0              11.3  ...          NaN
# 3                 90.4              17.5  ...          NaN
# 4                 85.6             11.25  ...          NaN
# ...                ...               ...  ...          ...
# 1355             93.15              17.3  ...          NaN
# 1356              95.5              20.5  ...          NaN
# 1357             120.0               NaN  ...          NaN
# 1362             60.14              8.75  ...          NaN
# 1363              83.0              10.3  ...          NaN
#
#      Oil change volume including oil filter Oil filters  \
# 0                                       NaN         NaN
# 1                                       NaN         NaN
# 2                                       NaN         NaN
# 3                                       NaN         NaN
# 4                                       NaN         NaN
# ...                                     ...         ...
# 1355                                    NaN         NaN
# 1356                                    NaN         NaN
# 1357                                    NaN         NaN
# 1362                                    NaN         NaN
# 1363                                    NaN         NaN
#
#      Cooling, overall volume Dry weight (base engine) Dry weight, kg  \
# 0                        NaN                      NaN            NaN
# 1                        NaN                      NaN            NaN
# 2                        NaN                      NaN            NaN
# 3                        NaN                      NaN            NaN
# 4                        NaN                      NaN            NaN
# ...                      ...                      ...            ...
# 1355                     NaN                      NaN            NaN
# 1356                     NaN                      NaN            NaN
# 1357                     NaN                      NaN          580.0
# 1362                     NaN                      NaN            NaN
# 1363                     NaN                      NaN            NaN
#
#      Combustion chamber working volume, cc  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 1355                                   NaN
# 1356                                   NaN
# 1357                                 48.07
# 1362                                   NaN
# 1363                                   NaN
#
#      Engine lifespan, thousand km— official information Max RPM      Type
# 0                                                   NaN     NaN       NaN
# 1                                                   NaN     NaN       NaN
# 2                                                   NaN     NaN       NaN
# 3                                                   NaN     NaN       NaN
# 4                                                   NaN     NaN       NaN
# ...                                                 ...     ...       ...
# 1355                                                NaN     NaN       NaN
# 1356                                                NaN     NaN       NaN
# 1357                                                NaN     NaN       NaN
# 1362                                                NaN     NaN  V-shaped
# 1363                                                NaN     NaN       NaN
#
# [1317 rows x 182 columns]

# %%
# Get all the unique values of the clean_car_df and the car_info column considering only the first element inside each list of the array
all_model_cars = clean_car_df['car_info'].apply(lambda x: x[:,0]).explode().unique()
# Transform the array into a list and transform the np.str_ into a string
all_model_cars = [str(x) for x in all_model_cars]
all_model_cars
# Out:
# ['Alfa Romeo MiTo I',
#  'Fiat Bravo II',
#  'Lancia Delta III',
#  'Alfa Romeo 156',
#  'Alfa Romeo 166',
#  'Lancia Lybra',
#  'Alfa Romeo GT II',
#  'Alfa Romeo GTV II',
#  'Alfa Romeo Spider V',
#  'Alfa Romeo 147',
#  'Fiat Stilo I',
#  'Alfa Romeo 159',
#  'Alfa Romeo Brera I',
#  'Alfa Romeo Spider VI',
#  'Alfa Romeo 4C',
#  'Alfa Romeo Giulietta',
#  'Alfa Romeo 145',
#  'Alfa Romeo 146',
#  'Alfa Romeo 155',
#  'Audi 80 B3',
#  'Audi 100 C4',
#  'Audi A6 C4',
#  'Audi 80 B4',
#  'Audi A4 B5',
#  'Audi A8 D2',
#  'Audi S4',
#  'Audi S6',
#  'Audi 100 C3',
#  'Audi 80',
#  'Audi 100',
#  'Audi A4',
#  'Audi A6',
#  'Audi A6 C5',
#  'Volkswagen Passat B5',
#  'Audi A3 1 (8L)',
#  'Seat Cordoba 1 (6K)',
#  'Seat Ibiza 2 (6K)',
#  'Seat Leon 1 (1M)',
#  'Seat Toledo 2 (1M)',
#  'Skoda Octavia 1 (1U)',
#  'Volkswagen Bora 1 (1J)',
#  'Volkswagen Golf 4 (1J)',
#  'Volkswagen Polo 3 Classic (6V)',
#  'Volkswagen Passat',
#  'Audi A6 Allroad',
#  'Audi A8',
#  'Audi A4 B7',
#  'Audi A6 C6',
#  'Audi A8 D3',
#  'Audi Q7',
#  'Volkswagen Touareg',
#  'Audi A4 B6 (8E)',
#  'Audi A4 B7 (8E)',
#  'Audi A6 C5 (4B)',
#  'Audi A6 C6 (4F)',
#  'Audi A8 D3 (4E)',
#  'Audi A4 B6',
#  'Audi A3',
#  'Seat Altea',
#  'Seat Toledo',
#  'Audi A4 B8',
#  'Audi A5 1.8 TFSI',
#  'Audi A3 2 (8P)',
#  'Audi Q3 1 (8U)',
#  'Audi TT 2 (8J)',
#  'Volkswagen Beetle 2 (5C)',
#  'Volkswagen Jetta 5 (1K)',
#  'Volkswagen Passat CC (35)',
#  'Volkswagen Tiguan 1 (5N)',
#  'Seat Exeo 1',
#  'Audi A8 D4',
#  'Audi RS3',
#  'Audi TT',
#  'Audi A6 C7',
#  'Audi A7 C7',
#  'Audi RS6 C7',
#  'Audi RS7 C7',
#  'Audi A7',
#  'Audi Q3',
#  'A4 B9',
#  'A5 F5',
#  'Q5 FY',
#  'S4 B9',
#  'S5 2 F5',
#  'SQ5 2 FY',
#  'Audi A8 D5',
#  'Audi S8',
#  'Audi SQ7',
#  'Bentley Bentayga',
#  'Audi Q8 1',
#  'Audi RS Q3',
#  'Audi TT RS',
#  'Audi SQ8',
#  'Audi RS4',
#  'Audi RS5',
#  'Audi RS3 3 (8V)',
#  'Audi RS Q3 2 (F3)',
#  'Audi TT RS 3 (8S)',
#  'Audi 80 B2',
#  'Volkswagen Passat B2',
#  'Audi 90 B3',
#  'BMW 2-Series F45',
#  'BMW 2-Series F46',
#  'BMW 1-Series F40',
#  'BMW 2-Series F44',
#  'BMW X1 F48',
#  'BMW X2 F39',
#  'BMW 1-Series F20',
#  'BMW 2-Series F22',
#  'BMW 3-Series F30',
#  'BMW 4-Series F32',
#  'BMW 5-Series G30',
#  'BMW 6-Series G32',
#  'BMW 7-Series G11',
#  'BMW E12 520/6',
#  'BMW 520i',
#  'M20B25',
#  'E9 3.0 CSi',
#  'BMW 16i',
#  'BMW 18i',
#  'BMW E36 318i',
#  'BMW E34 518i',
#  'BMW E36 Z3',
#  'BMW',
#  'BMW M50B20',
#  'BMW M50B20TU',
#  'BMW M20B25',
#  'BMW M50B25',
#  'BMW M50B24',
#  'BMW S50B30',
#  'BMW S50B32',
#  'BMW M52B25',
#  'BMW M52TUB25',
#  'BMW 28i',
#  'BMW E46',
#  'BMW E39',
#  'BMW N54',
#  'M60B30',
#  'M60B40',
#  'BMW M62B35',
#  'BMW M62TUB35',
#  'M60',
#  'M62',
#  'M62TUB44',
#  'BMW X5 E53',
#  'BMW E39 B10',
#  'BMW 7-Series E32',
#  'BMW 8-Series E31',
#  'BMW 7-Series E38',
#  'Rolls-Royce Silver Seraph 1',
#  'BMW F10 520i',
#  'BMW G30 520i',
#  'BMW G20 320i',
#  'BMW N20B20',
#  'BMW N43B20',
#  'BMW 1 Series',
#  'BMW 320si E90',
#  'BMW E46 316',
#  'BMW 23i',
#  'BMW 25i',
#  'BMW 30i',
#  'N53',
#  'N52',
#  'N53B25',
#  'N53B30',
#  'BMW 1-Series E87',
#  'BMW 3-Series E90',
#  'BMW 5-Series E60',
#  'BMW 7-Series F01',
#  'BMW X6 E71',
#  'BMW Z4 E89',
#  'BMW 5-Series F07',
#  'BMW 5-Series F10',
#  'BMW 6-Series F12',
#  'BMW X3 F25',
#  'BMW X4 F26',
#  'BMW X5 E70',
#  'BMW X5 F15',
#  'BMW X6 F16',
#  'BMW F12/F13 650i',
#  'BMW F01/F02 750i/750Li',
#  'BMW 6-Series F06',
#  'BMW 8-Series G15',
#  'BMW X7 G07',
#  'BMW 7-Series E65',
#  'BMW 7-Series E66',
#  'Rolls-Royce Phantom',
#  'Rolls-Royce Ghost',
#  'Rolls-Royce Wraith',
#  'BMW M760Li xDrive',
#  'Rolls-Royce Dawn',
#  'Rolls-Royce Cullinan',
#  'BMW M5 E34',
#  'BMW S38B38',
#  'M3',
#  'M3 GTR E36',
#  'M3 GT E36',
#  'M3-R E36',
#  'BMW M3',
#  'S52B32',
#  'BMW Z3M',
#  'BMW Z4M',
#  'BMW S62',
#  'BMW X6M',
#  'BMW E60 M5',
#  'BMW E61 M5',
#  'BMW E63 M6',
#  'BMW E64 M6',
#  'Chevrolet Beat M300',
#  'Chevrolet Spark M300',
#  'Daewoo Matiz 3',
#  'Chevrolet Spark M200',
#  'Daewoo Matiz',
#  'Chevrolet Aveo',
#  'Chevrolet Spark',
#  'Ravon R2',
#  'Chevrolet Aveo T200',
#  'Chevrolet Aveo T250',
#  'Daewoo Kalos T200',
#  'Chevrolet Cobalt',
#  'Chevrolet Sail',
#  'Chevrolet Spin',
#  'Ravon Gentra',
#  'Ravon Nexia',
#  'Daewoo Gentra',
#  'Chevrolet Lacetti J200',
#  'Chevrolet Aveo T300',
#  'Chevrolet Lanos T150',
#  'Chevrolet Cruze',
#  'Chevrolet Lacetti',
#  'Chevrolet Lanos',
#  'Chevrolet Orlando',
#  'Chevrolet Epica',
#  'Daewoo Tosca',
#  'Chevrolet Evanda V200',
#  'Chevrolet Epica V250',
#  'Daewoo Magnus V200',
#  'Daewoo Tosca V250',
#  'Chevrolet Malibu',
#  'Chevrolet Captiva C100',
#  'Chevrolet Cruze 1 (J300)',
#  'Opel Antara',
#  'Chevrolet Captiva',
#  'Chrysler Neon',
#  'Chrysler Neon 1',
#  'Chrysler Neon 2',
#  'Chrysler Sebring 1',
#  'Chrysler Sebring 2',
#  'Chrysler PT Cruiser 1',
#  'Dodge Avenger 1 Coupe',
#  'Dodge Neon 1',
#  'Eagle Talon 2',
#  'Mitsubishi Eclipse 2G',
#  'Plymouth Neon 1',
#  'Chrysler Sebring',
#  'Dodge Avenger',
#  'Dodge Caliber',
#  'Dodge Journey',
#  'Jeep Compass',
#  'Jeep Patriot',
#  'Chrysler PT Cruiser',
#  'Chrysler Cirrus',
#  'Chrysler Voyager',
#  'Dodge Caravan',
#  'Dodge Stratus',
#  'Jeep Liberty',
#  'Jeep Wrangler',
#  'Plymouth Breeze',
#  'Plymouth Voyager',
#  'Gaz Volga',
#  'Gaz Volga Siber',
#  'Chrysler 300M',
#  'Chrysler 300C',
#  'Chrysler Concorde',
#  'Chrysler Intrepid',
#  'Dodge Charger',
#  'Dodge Intrepid',
#  'Dodge Magnum',
#  'Chrysler Grand Voyager',
#  'Chrysler Imperial',
#  'Chrysler New Yorker',
#  'Chrysler Town & Country',
#  'Dodge Grand Caravan',
#  'Dodge Dynasty',
#  'Eagle Vision',
#  'Plymouth Grand Voyager',
#  'Chrysler LHS',
#  'Plymouth Prowler',
#  'Chrysler Sebring 3',
#  'Dodge Avenger 1',
#  'Dodge Journey 1',
#  'Dodge Challenger',
#  'Chrysler Pacifica',
#  'Chrysler Town&Country',
#  'Volkswagen Routan',
#  'Chrysler Voyager 4',
#  'Jeep Cherokee 3',
#  'Chrysler 200',
#  'Dodge Durango',
#  'Jeep Grand Cherokee',
#  'Fiat Freemont',
#  'Lancia Thema',
#  'Jeep Commander',
#  'Daewoo Nexia',
#  'Daewoo Espero',
#  'Daewoo Lanos',
#  'Daewoo Lanos T150',
#  'Daewoo Nubira',
#  'Daewoo Tacuma',
#  'Chevrolet Spark 1',
#  'Chevrolet Spark 2',
#  'Daewoo Matiz M100',
#  'Daewoo Matiz M150',
#  'Daewoo Matiz M200',
#  'Daewoo Tico A100',
#  'Daewoo Leganza',
#  'Daewoo Evanda V200',
#  'Daewoo Lacetti J200',
#  'Daewoo Leganza V100',
#  'Daewoo Nubira J150',
#  'Daewoo Tacuma U100',
#  'Chevrolet Evanda 1 (V200)',
#  'Chevrolet Lacetti 1 (J200)',
#  'Chrysler Stratus 1',
#  'Chrysler Voyager 3',
#  'Dodge Neon 2',
#  'Dodge Stratus 1',
#  'Plymouth Neon 2',
#  'Dodge Neon',
#  'Dodge Caliber 1',
#  'Jeep Compass 1',
#  'Jeep Patriot 1',
#  'Lancia Flavia',
#  'Dodge Caliber SRT4',
#  'Chrysler Grand Voyager 3',
#  'Chrysler Grand Voyager 4',
#  'Chrysler Grand Voyager 5',
#  'Chrysler Imperial 7',
#  'Chrysler New Yorker 13',
#  'Chrysler Pacifica 1',
#  'Chrysler Town & Country 2',
#  'Chrysler Town & Country 3',
#  'Chrysler Town & Country 4',
#  'Chrysler Town & Country 5',
#  'Dodge Caravan 2',
#  'Dodge Caravan 3',
#  'Dodge Caravan 4',
#  'Dodge Dynasty 1',
#  'Dodge Grand Caravan 2',
#  'Dodge Grand Caravan 3',
#  'Dodge Grand Caravan 4',
#  'Dodge Grand Caravan 5',
#  'Jeep Wrangler 3',
#  'Plymouth Grand Voyager 2',
#  'Plymouth Grand Voyager 3',
#  'Plymouth Voyager 2',
#  'Plymouth Voyager 3',
#  'Volkswagen Routan 1',
#  'Dodge Nitro',
#  'Dodge Ram',
#  'Chrysler 300C 1 (LX)',
#  'Chrysler 300C 2 (LD)',
#  'Dodge Charger 1 (LX)',
#  'Dodge Charger 2 (LD)',
#  'Dodge Challenger 3 (LC)',
#  'Dodge Durango 3 (WD)',
#  'Dodge Ram 4 (DS)',
#  'Jeep Commander 1 (XK)',
#  'Jeep Grand Cherokee 3 (WK)',
#  'Jeep Grand Cherokee 4 (WK2)',
#  'Fiat 500 II',
#  'Fiat 500C II',
#  'Fiat Panda II',
#  'Fiat Panda III',
#  'Fiat Grande Punto I',
#  'Fiat Punto IV',
#  'Ford Ka 2',
#  'Lancia Ypsilon I',
#  'Lancia Ypsilon II',
#  'Fiat Palio I',
#  'Fiat Punto I',
#  'Fiat Bravo I',
#  'Fiat Coupe I',
#  'Fiat Marea I',
#  'Fiat Brava I',
#  'Fiat Brava',
#  'Fiat Bravo',
#  'Fiat Marea',
#  'Fiat Multipla I',
#  'Lancia Dedra I',
#  'Fiat Doblo I',
#  'Fiat Siena I',
#  'Fiat Strada I',
#  'Lancia Lybra I',
#  'Fiat Panda I',
#  'Fiat Seicento I',
#  'Fiat Punto II',
#  'Fiat Uno I',
#  'Lancia Y I',
#  'Fiat Albea I',
#  'Fiat Idea I',
#  'Lancia Thesis I',
#  'Alfa Romeo MiTo',
#  'Fiat Linea I',
#  'Fiat Doblo II',
#  'Opel Combo D',
#  'Fiat Doblo',
#  'Fiat Grande Punto',
#  'Fiat Linea',
#  'Fiat Fiorino III',
#  'Lancia Musa I',
#  'Fiat Tipo II',
#  'Fiat 500L II',
#  'Fiat Ducato III',
#  'Fiat Sedici I',
#  'Fiat 500X',
#  'Fiat Palio',
#  'Fiat Punto',
#  'Fiat Siena',
#  'Fiat Strada',
#  'Fiat Tipo',
#  'Fiat Albea',
#  'Fiat Fiorino',
#  'Fiat Idea',
#  'Fiat Panda',
#  'Lancia Musa',
#  'Lancia Ypsilon',
#  'Fiat Argo I',
#  'Fiat Cronos I',
#  'Fiat Palio II',
#  'Fiat Toro I',
#  'Jeep Renegade 1',
#  'Fiat Croma II',
#  'Ford Fiesta',
#  'Ford Fusion',
#  'Mazda 2',
#  'Fiesta',
#  'B-Max',
#  'Ford C-Max',
#  'Ford 1.6 TDCi',
#  'Land Rover Freelander II',
#  'Ford Mondeo',
#  'Ford Galaxy',
#  'Ford S-Max',
#  'Ford Explorer',
#  'Ford Mustang',
#  'Ford Ranger',
#  'Ford Fiesta Mk5',
#  'Ford Focus Mk1',
#  'Ford Scorpio',
#  'Ford Transit Mk6',
#  'Ford Mondeo Mk3',
#  'Ford Galaxy Mk1',
#  'Ford Focus',
#  'Ford Fusion Mk1',
#  'Ford Escort USA Mk3',
#  'Ford C-Max Mk1',
#  'Ford Connect Mk1',
#  'Ford Ka',
#  'Ford Fiesta Mk4',
#  'Ford Focus Mk3',
#  'Ford C-Max Mk2',
#  'Ford Kuga',
#  'Ford Transit Mk7',
#  'Ford Galaxy Mk2',
#  'Ford S-MAX Mk1',
#  'Ford Escort',
#  'Ford Kuga Mk2',
#  'Ford Puma Mk1',
#  'Ford Mondeo Mk1',
#  'Ford Mondeo Mk2',
#  'Ford Mondeo Mk4',
#  'Ford S-MAX',
#  'Ford Focus Mk3 ST',
#  'Ford Sierra Mk2',
#  'Ford Escort Mk6',
#  'Ford Kuga Mk1',
#  'Ford B-Max',
#  'Ford Focus Mk3 RS',
#  'Honda CR-X 2',
#  'Honda CR-X 3',
#  'Honda Civic 4',
#  'Honda Civic 5',
#  'Honda Civic 6',
#  'Honda Integra 2',
#  'Honda Civic Type R',
#  'Honda Domani 1',
#  'Honda Integra 3',
#  'Honda Orthia 1',
#  'Honda Civic',
#  'Honda Integra',
#  'Honda CR-V 1',
#  'Honda S-MX 1',
#  'Honda Stepwgn 1',
#  'Honda Accord 5',
#  'Honda Legend 1',
#  'Rover 800 1',
#  'Acura NSX',
#  'Honda NSX',
#  'Acura TL',
#  'Daewoo Arcadia',
#  'Honda Inspire',
#  'Honda Legend',
#  'Honda Saber',
#  'Acura RL',
#  'Honda City',
#  'Honda Logo',
#  'Honda Concerto',
#  'Honda Capa 1',
#  'Honda City 3',
#  'Honda Civic 7',
#  'Honda Concerto 1',
#  'Honda CR-X 1',
#  'Honda Integra 1',
#  'Rover 200 II',
#  'Rover 400 I',
#  'Acura EL',
#  'Honda FR-V',
#  'Honda Stream',
#  'Honda Accord',
#  'Honda Ascot',
#  'Honda Ascot Innova',
#  'Honda Prelude',
#  'Rover 620i',
#  'Honda Accord 6',
#  'Honda S2000',
#  'Acura CL 1',
#  'Honda Odyssey 1',
#  'Honda Prelude 4',
#  'Honda Prelude 5',
#  'Acura CL',
#  'Honda Odyssey',
#  'Honda Rafaga',
#  'Honda Vigor',
#  'Honda Ascot Innova 1',
#  'Rover 600 1',
#  'Acura TL 2',
#  'Honda Inspire 3',
#  'Honda Saber 2',
#  'Honda Avancier',
#  'Acura CL 2',
#  'Acura TL 3',
#  'Acura MDX',
#  'Honda Pilot',
#  'Honda Ridgeline',
#  'Acura RSX',
#  'Honda CR-V',
#  'Honda Stepwgn',
#  'Acura TSX',
#  'Honda Accord 7',
#  'Honda Accord 8',
#  'Honda CR-V 2',
#  'Honda CR-V 3',
#  'Honda CR-V 4',
#  'Honda Element 1',
#  'Honda Elysion 1',
#  'Honda Odyssey 3',
#  'Honda Odyssey 4',
#  'Honda Stepwgn 2',
#  'Honda Stepwgn 3',
#  'K24W',
#  'Honda Fit',
#  'Honda Jazz',
#  'Honda Fit 3',
#  'Honda Fit 4',
#  'Honda Jazz 3',
#  'Honda Freed',
#  'Honda HR-V',
#  'Honda Jade',
#  'Honda Civic 9',
#  'Honda Civic 10',
#  'Honda HR-V 2',
#  'Honda Civic 8',
#  'Honda FR-V 1',
#  'Honda City 5',
#  'Honda Stream 2',
#  'Acura ILX',
#  'Proton Perdana',
#  'HD250',
#  'HD260',
#  'HD270',
#  'HD500',
#  'HD1000',
#  'Hyundai Eon',
#  'Hyundai Casper',
#  'Hyundai i10',
#  'Kia Picanto',
#  'Hyundai Bayon',
#  'Hyundai Kona',
#  'Hyundai i20',
#  'Hyundai i30',
#  'Kia Ceed',
#  'Kia Rio',
#  'Kia Stonic',
#  'Hyundai Accent 1',
#  'Hyundai Accent',
#  'Hyundai Accent 2',
#  'Hyundai Getz 1',
#  'Hyundai Lantra',
#  'Hyundai Scoupe',
#  'Hyundai Accent 5',
#  'Hyundai Creta 2',
#  'Hyundai Elantra 7',
#  'Hyundai Stargazer 1',
#  'Kia Carens 5',
#  'Kia Cerato 4',
#  'Kia Seltos 1',
#  'Kia Sonet 1',
#  'Hyundai Custo 1',
#  'Hyundai Mistra 2',
#  'Hyundai Sonata 8',
#  'Hyundai Tucson 4',
#  'Kia K5 3',
#  'Kia Sportage Ace 3',
#  'Hyundai Tucson',
#  'Kia Sportage',
#  'Hyundai Coupe',
#  'Hyundai Lantra 2',
#  'Hyundai Coupe 1',
#  'Hyundai Atos',
#  'Hyundai Getz',
#  'Kia Sonet',
#  'Hyundai Custo',
#  'Hyundai Sonata',
#  'Kia Carnival',
#  'Kia K5',
#  'Hyundai Grandeur XG',
#  'Hyundai Grandeur 5',
#  'Hyundai Grandeur 6',
#  'Genesis G90',
#  'Hyundai Carnival',
#  'Hyundai Terracan',
#  'Kia Terracan',
#  'Genesis G80',
#  'Genesis GV70',
#  'Genesis GV80',
#  'Kia Ray',
#  'Kia Picanto 2',
#  'Kia Picanto 3',
#  'Kia Ray 1',
#  'Hyundai Venue',
#  'Hyundai Grandeur',
#  'Kia Joice',
#  'Hyundai Elantra',
#  'Hyundai Matrix',
#  'Kia Cerato',
#  'Hyundai ix20',
#  'Hyundai Solaris',
#  'Kia ProCeed',
#  'Kia Venga',
#  'Hyundai Accent 4',
#  'Hyundai Elantra 4',
#  'Hyundai i20 1',
#  'Hyundai ix20 1',
#  'Hyundai i30 1',
#  'Hyundai Solaris 1',
#  'Kia Carens 3',
#  'Kia Cerato 1',
#  'Kia Cerato 2',
#  'Kia Ceed 1',
#  'Kia ProCeed 1',
#  'Kia Rio 3',
#  'Kia Soul 1',
#  'Kia Venga 1',
#  'Hyundai Elantra 5',
#  'Hyundai i30 2',
#  'Hyundai i40 1',
#  'Hyundai ix35 1',
#  'Hyundai Tucson 3',
#  'Hyundai Veloster 1',
#  'Kia Carens 4',
#  'Kia Ceed 2',
#  'Kia ProCeed 2',
#  'Kia Soul 2',
#  'Kia Sportage 3',
#  'Kia Sportage 4',
#  'Hyundai Creta 1',
#  'Hyundai Elantra 6',
#  'Hyundai i30 3',
#  'Hyundai Solaris 2',
#  'Kia Cerato 3',
#  'Kia Rio 4',
#  'Kia Rio X-Line 1',
#  'Kia Rio X 1',
#  'Hyundai Kona 1',
#  'Hyundai Sonata 7',
#  'Hyundai Veloster 2',
#  'Kia Ceed 3',
#  'Kia ProCeed 3',
#  'Kia Optima 4',
#  'Kia Soul 3',
#  'Kia XCeed 1',
#  'Hyundai Venue 1',
#  'Hyundai Santa Fe',
#  'Kia Sorento',
#  'Hyundai Coupe 2',
#  'Hyundai Elantra 3',
#  'Hyundai Sonata 4',
#  'Hyundai Trajet 1',
#  'Hyundai Tucson 1',
#  'Kia Carens 2',
#  'Kia Sportage 2',
#  'Hyundai Atos Prime',
#  'Kia Visto',
#  'Hyundai Amica',
#  'Amica',
#  'Kia Magentis',
#  'Hyundai Santa Fe 1',
#  'Kia Magentis 1',
#  'Hyundai Starex',
#  'Kia Carens',
#  'Hyundai Sonata 5 (NF)',
#  'Hyundai Sonata 6 (YF)',
#  'Hyundai ix35 1 (LM)',
#  'Kia Cerato 2 (TD)',
#  'Kia Magentis 2 (MG)',
#  'Kia Optima 3 (TF)',
#  'Kia Sportage 3 (SL)',
#  'Hyundai Santa Fe 3',
#  'Hyundai Santa Fe 4',
#  'Hyundai Sonata 6',
#  'Kia Optima 3',
#  'Kia Sorento 3',
#  'Hyundai i20 2',
#  'Kia Stonic 1',
#  'Hyundai Ioniq 1',
#  'Kia Niro 1',
#  'Kia XCeed',
#  'Hyundai i40',
#  'Hyundai ix35',
#  'Hyundai Elantra 5 (MD)',
#  'Hyundai i40 1 (VF)',
#  'Hyundai Sonata 7 (LF)',
#  'Hyundai Tucson 3 (TL)',
#  'Kia Carens 4 (RP)',
#  'Kia Cerato 3 (YD)',
#  'Kia Optima 4 (JF)',
#  'Kia Sportage 4 (QL)',
#  'Kia Soul 2 (PS)',
#  'Kia Optima',
#  'Hyundai Veloster',
#  'Kia Seltos',
#  'Kia Soul',
#  'Kia Sportage 5',
#  'Hyundai Coupe 2 (GK)',
#  'Hyundai Sonata 4 (EF)',
#  'Hyundai Santa Fe 1 (SM)',
#  'Hyundai Tucson 1 (JM)',
#  'Hyundai Trajet 1 (FO)',
#  'Kia Magentis 1 (GD)',
#  'Kia Opirus 1 (GH)',
#  'Kia Sportage 2 (KM)',
#  'Hyundai Grandeur 3',
#  'Hyundai Dynasty 1 (LX)',
#  'Hyundai Equus 1 (LZ)',
#  'Hyundai Grandeur 1 (L)',
#  'Hyundai Grandeur 2 (LX)',
#  'Hyundai Grandeur 3 (XG)',
#  'Hyundai Starex 1 (A1)',
#  'Hyundai Equus',
#  'Kia Opirus',
#  'Hyundai Entourage 1 (EP)',
#  'Hyundai Grandeur 4 (TG)',
#  'Hyundai ix55 1 (EN)',
#  'Kia Carnival 2 (VQ)',
#  'Kia Mohave 1 (HM)',
#  'Kia Sorento 1 (BL)',
#  'Hyundai Santa Fe 2 (CM)',
#  'Hyundai Palisade',
#  'Kia Cadenza',
#  'Hyundai Grand Santa Fe',
#  'Hyundai Genesis',
#  'Genesis G80 1 (DH)',
#  'Hyundai Genesis 1 (BH)',
#  'Genesis 2 (DH)',
#  'Hyundai Grandeur 5 (HG)',
#  'Hyundai Grand Santa Fe 1 (NC)',
#  'Hyundai Santa Fe 3 (DM)',
#  'Kia Cadenza 1 (VG)',
#  'Kia Carnival 3 (YP)',
#  'Kia Quoris 1 (KH)',
#  'Kia Sorento 3 (UM)',
#  'Hyundai G80',
#  'Hyundai G90',
#  'Genesis',
#  'Hyundai Genesis Coupe',
#  'Kia Quoris',
#  'Kia K900',
#  'Kia Telluride',
#  'Genesis G70',
#  'Kia Stinger',
#  'Kia K8',
#  'Hyundai Staria',
#  'Hyundai Grandeur 4',
#  'Hyundai Santa Fe 2',
#  'Kia Cadenza 1',
#  'Kia Carnival 2',
#  'Kia Magentis 2',
#  'Kia Opirus 1',
#  'Kia Mohave',
#  'Hyundai Equus 2 (VI)',
#  'Kia K900 2 (RJ)',
#  'Genesis G90 1 (HI)',
#  'Isuzu Faster 3',
#  'Isuzu MU 1',
#  'Isuzu Trooper 1',
#  'Isuzu Wizard 1',
#  'Opel Frontera A',
#  'Isuzu Trooper 2',
#  'Opel Monterey A',
#  'Honda Horizon 1',
#  'Isuzu D-Max 1',
#  'Isuzu D-Max 2',
#  'Isuzu MU-7 1',
#  'Isuzu MU-X 1',
#  'Isuzu D-Max',
#  'Isuzu MU-X',
#  'Mazda BT-50',
#  'Isuzu MU 2',
#  'Isuzu Rodeo 2',
#  'Isuzu Wizard 2',
#  'Isuzu Faster 2',
#  'Isuzu Impulse 1',
#  'Honda Passport 1',
#  'SsangYong Korando Family',
#  'Isuzu VehiCROSS 1',
#  'Opel Frontera B',
#  'Honda Passport 2',
#  'Acura SLX',
#  'Isuzu Axiom 1',
#  'Jaguar XE 1 (X760)',
#  'Jaguar XF 1 (X250)',
#  'Jaguar XF 2 (X260)',
#  'Jaguar XJ 8 (X351)',
#  'Jaguar F-Pace 1 (X761)',
#  'Jaguar F-Type 1 (X152)',
#  'Jaguar XF',
#  'Jaguar XJ',
#  'Jaguar XK',
#  'Jaguar XE',
#  'Jaguar F-Pace',
#  'Jaguar F-Type',
#  'Jaguar X-Type',
#  'Jaguar E-Pace',
#  'Jaguar S-Type',
#  'Jaguar XJ 6',
#  'Jaguar XK 1',
#  'Lincoln LS',
#  'Jaguar S-Type 1',
#  'Jaguar XJ 7',
#  'Jaguar XK 2',
#  'Jaguar XF 1',
#  'Jaguar XFR',
#  'Dodge Dart',
#  'Jeep Cherokee',
#  'Jeep Renegade',
#  'Dodge Dakota 2',
#  'Dodge Dakota 3',
#  'Dodge Durango 2',
#  'Dodge Nitro 1',
#  'Dodge Ram 3',
#  'Dodge Ram 4',
#  'Jeep Cherokee 4',
#  'Jeep Commander 1',
#  'Jeep Grand Cherokee 3',
#  'Mitsubishi Raider 1',
#  'Dodge Dakota 1',
#  'Dodge Durango 1',
#  'Dodge Ramcharger 2',
#  'Dodge Ram 1',
#  'Dodge Ram 2',
#  'Jeep Grand Cherokee 1',
#  'Dodge Dakota',
#  'Dodge Ramcharger',
#  'Chrysler Voyager 2',
#  'Jeep Cherokee 2',
#  'Chrysler Grand Voyager 5 (RT)',
#  'Dodge Nitro 1 (KA)',
#  'Jeep Cherokee 4 (KK)',
#  'Jeep Wrangler 3 (JK)',
#  'Dodge Dakota 1 (AN)',
#  'Dodge Dakota 2 (DN)',
#  'Eagle Premier',
#  'Jeep Cherokee 2 (XJ)',
#  'Jeep Comanche 1 (MJ)',
#  'Jeep Wrangler 1 (YJ)',
#  'Jeep Wrangler 2 (TJ)',
#  'Chrysler Pacifica 2',
#  'Chrysler Voyager 6',
#  'Dodge Durango 3',
#  'Dodge Ram 5',
#  'Jeep Grand Cherokee 4',
#  'Jeep Grand Cherokee 5',
#  'Jeep Gladiator 2',
#  'Jeep Wrangler 4',
#  'Jeep Grand Cherokee 1 (ZJ)',
#  'Jeep Grand Cherokee 2 (WJ)',
#  'Chrysler Aspen',
#  'Mitsubishi Raider',
#  'Dodge Dakota 3 (ND)',
#  'Dodge Ram 3 (DT)',
#  'Jeep Grand Cherokee WJ',
#  'Jeep Gladiator',
#  'RAM 1500',
#  'Maserati Levante',
#  'Kia Sephia',
#  'Kia Shuma',
#  'Kia Sephia 1',
#  'Kia Sephia 2',
#  'Kia Shuma 1',
#  'Kia Clarus',
#  'Kia Spectra',
#  'Kia Carens 2 (FJ)',
#  'Kia Shuma 2 (SD)',
#  'Kia Spectra 1 (SD)',
#  'Land Rover Defender',
#  'Land Rover Discovery',
#  'Land Rover Defender 1',
#  'Land Rover Discovery 2',
#  'Land Rover Discovery 1',
#  'Land Rover Range Rover 1',
#  'Land Rover Freelander',
#  'Rover 75',
#  'MG ZT',
#  'Land Rover Defender 2',
#  'Land Rover Discovery 5',
#  'Land Rover Discovery Sport 1',
#  'Land Rover Range Rover Evoque 1',
#  'Land Rover Range Rover Sport 2',
#  'Land Rover Range Rover Velar 1',
#  'Land Rover Range Rover Evoque 2',
#  'Land Rover Freelander 2',
#  'Land Rover Range Rover II',
#  'Land Rover Discovery 3',
#  'Land Rover Discovery 4',
#  'Land Rover Range Rover Sport 1',
#  'Land Rover Range Rover 3',
#  'Land Rover Range Rover 4',
#  'Land Rover Range Rover 5',
#  'Land Rover Range Rover 3 (L322)',
#  'Land Rover Range Rover Sport 1 (L320)',
#  'Land Rover Range Rover 2',
#  'Range Rover 4 (L405)',
#  'Land Rover Range Rover Sport 2 (L494)',
#  'TGS',
#  'TGX',
#  'D2866 LF34',
#  'MAN D2868',
#  'MAN TGX',
#  'MAN D3876',
#  'Mazda RX-8',
#  'Mazda 6',
#  'Mazda MPV',
#  'Mazda Tribute',
#  'Mazda Tribute EP2',
#  'Mazda 121 DA',
#  'Mazda 121 DB',
#  'Kia Pride 1 (DA)',
#  'Mazda 121',
#  'Mazda Autozam Revue',
#  'Mazda 323',
#  'Mazda Familia',
#  'Kia Pride',
#  'Mazda Autozam Revue DB',
#  'Mazda Demio DW',
#  'Mazda Familia BH',
#  'Mazda Familia BJ',
#  'Mazda Etude BF',
#  'Mazda Familia BF',
#  'Mazda 323 BG',
#  'Mazda Autozam AZ-3 EC',
#  'Mazda Eunos 100 BG',
#  'Eunos Presso EC',
#  'Mazda Familia BG',
#  'Mazda Demio',
#  'Kia Avella',
#  'Ford Laser',
#  'Mercury Tracer',
#  'Mazda MX-3',
#  'Mazda Xedos 6',
#  'Kia Rio 1',
#  'Kia Shuma 2',
#  'Kia Spectra 1',
#  'Mazda 323 BH',
#  'Mazda Lantis CB',
#  'Mazda MX-5 NA',
#  'Mazda MX-5 NB',
#  'Mazda Protege BG',
#  'Mazda Protege BH',
#  'Kia Carens 1 (FC)',
#  'Kia Clarus 1 (FE)',
#  'Kia Sephia 1 (FA)',
#  'Kia Sephia 2 (FB)',
#  'Kia Shuma 1 (FB)',
#  'Suzuki Baleno 1 (EG)',
#  'Mazda CX-9',
#  'Mazda CX-9 I (TB)',
#  'Mazda 626 GD',
#  'Mazda 929 HC',
#  'Mazda B-series 4 (UF)',
#  ...]

# %%
# get all the cars that have the brand word in it:
# We put all the cars in lower case and the brand in lower case and check if the brand is in the car name
brand_cars = sorted([x for x in all_model_cars if brand.lower() in x.lower()])
brand_cars
# Out:
# ['Audi 100',
#  'Audi 100 C3',
#  'Audi 100 C4',
#  'Audi 80',
#  'Audi 80 B2',
#  'Audi 80 B3',
#  'Audi 80 B4',
#  'Audi 90 B3',
#  'Audi A1',
#  'Audi A2',
#  'Audi A3',
#  'Audi A3 1',
#  'Audi A3 1 (8L)',
#  'Audi A3 2',
#  'Audi A3 2 (8P)',
#  'Audi A4',
#  'Audi A4 B5',
#  'Audi A4 B6',
#  'Audi A4 B6 (8E)',
#  'Audi A4 B7',
#  'Audi A4 B7 (8E)',
#  'Audi A4 B8',
#  'Audi A5 1.8 TFSI',
#  'Audi A6',
#  'Audi A6 Allroad',
#  'Audi A6 C4',
#  'Audi A6 C5',
#  'Audi A6 C5 (4B)',
#  'Audi A6 C6',
#  'Audi A6 C6 (4F)',
#  'Audi A6 C7',
#  'Audi A7',
#  'Audi A7 C7',
#  'Audi A8',
#  'Audi A8 D2',
#  'Audi A8 D3',
#  'Audi A8 D3 (4E)',
#  'Audi A8 D4',
#  'Audi A8 D5',
#  'Audi Q3',
#  'Audi Q3 1 (8U)',
#  'Audi Q7',
#  'Audi Q8 1',
#  'Audi RS Q3',
#  'Audi RS Q3 2 (F3)',
#  'Audi RS3',
#  'Audi RS3 3 (8V)',
#  'Audi RS4',
#  'Audi RS5',
#  'Audi RS6 C7',
#  'Audi RS7 C7',
#  'Audi S4',
#  'Audi S6',
#  'Audi S8',
#  'Audi SQ7',
#  'Audi SQ8',
#  'Audi TT',
#  'Audi TT 2 (8J)',
#  'Audi TT RS',
#  'Audi TT RS 3 (8S)']

# %%
# Create a dataframe with the list of the cars of the brand
brand_df = pd.DataFrame(brand_cars, columns=['motolist_name'])
# Create three empty columns 'cleaned_name'
brand_df['cleaned_name'] = ''
# Rearrenge the columns so clenaed_name is the first column
brand_df = brand_df[['cleaned_name', 'motolist_name']]
brand_df
# Out:
#    cleaned_name      motolist_name
# 0                         Audi 100
# 1                      Audi 100 C3
# 2                      Audi 100 C4
# 3                          Audi 80
# 4                       Audi 80 B2
# 5                       Audi 80 B3
# 6                       Audi 80 B4
# 7                       Audi 90 B3
# 8                          Audi A1
# 9                          Audi A2
# 10                         Audi A3
# 11                       Audi A3 1
# 12                  Audi A3 1 (8L)
# 13                       Audi A3 2
# 14                  Audi A3 2 (8P)
# 15                         Audi A4
# 16                      Audi A4 B5
# 17                      Audi A4 B6
# 18                 Audi A4 B6 (8E)
# 19                      Audi A4 B7
# 20                 Audi A4 B7 (8E)
# 21                      Audi A4 B8
# 22                Audi A5 1.8 TFSI
# 23                         Audi A6
# 24                 Audi A6 Allroad
# 25                      Audi A6 C4
# 26                      Audi A6 C5
# 27                 Audi A6 C5 (4B)
# 28                      Audi A6 C6
# 29                 Audi A6 C6 (4F)
# 30                      Audi A6 C7
# 31                         Audi A7
# 32                      Audi A7 C7
# 33                         Audi A8
# 34                      Audi A8 D2
# 35                      Audi A8 D3
# 36                 Audi A8 D3 (4E)
# 37                      Audi A8 D4
# 38                      Audi A8 D5
# 39                         Audi Q3
# 40                  Audi Q3 1 (8U)
# 41                         Audi Q7
# 42                       Audi Q8 1
# 43                      Audi RS Q3
# 44               Audi RS Q3 2 (F3)
# 45                        Audi RS3
# 46                 Audi RS3 3 (8V)
# 47                        Audi RS4
# 48                        Audi RS5
# 49                     Audi RS6 C7
# 50                     Audi RS7 C7
# 51                         Audi S4
# 52                         Audi S6
# 53                         Audi S8
# 54                        Audi SQ7
# 55                        Audi SQ8
# 56                         Audi TT
# 57                  Audi TT 2 (8J)
# 58                      Audi TT RS
# 59               Audi TT RS 3 (8S)

# %%
# Save the dataframe to a xsxl file
brand_df.to_excel(os.path.join(motorlist_relationships_dir, f'{brand.lower()}_cars.xlsx'), index=False)

# %% [markdown]
# ### 3. Wallapop
